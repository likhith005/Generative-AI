# %% [markdown]
# <a href="https://colab.research.google.com/github/likhith005/Generative-AI/blob/master/StyleTransferGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code Link: https://colab.research.google.com/drive/1-1_Z23sZwn-RdU0taxRF2-19fxYrFVHJ?usp=sharing

# %%
#import the libraries
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
#import the images
def load_image(img_path):
  img = tf.io.read_file(img_path)
  img = tf.image.decode_image(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)
  img = img[tf.newaxis, :]
  return img

# %%
#Implementation of style Transfer with GANs
#Load the content & style images
content_image = load_image('/content/frida.jpg')
style_image = load_image('/content/Claude-Monet-French-Impressionist-painter.jpeg')

# %%
# Visualization of images
plt.imshow(np.squeeze(syle_image))
plt.show()
plt.imshow(np.squeeze(content_image))
plt.show()

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

stylized_image = model(tf.constant(content_image),tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.show()
cv2.imwrite('generated_img.jpg',cv2.cvtColor(np.squeeze(stylized_image)*255,cv2.COLOR_BGR2RGB))
# Out:
# True

# %% [markdown]
# **Scenario 1** :
#
# You are tasked with creating a style transfer model using GANs to transform a photograph of a cityscape into a painting in the style of Vincent van Gogh's "Starry Night."
#
# Solution:
#
# Collect a dataset of cityscape photographs and paintings in the style of "Starry Night."
#
# Preprocess the images and extract features using a pre-trained neural network.
#
# Implement a GAN architecture with a generator and discriminator.
#
# Train the GAN using the cityscape photographs as input and the "Starry Night" style paintings as target outputs.
#
# Fine-tune the generator using adversarial training and feature matching techniques to improve the quality of the stylized images.
#
# Evaluate the model's performance using qualitative and quantitative metrics such as visual inspection and perceptual similarity scores.

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# Load the content & style images
content_image = load_image('/content/cityscape.jpg')
style_image = load_image('/content/Van_Gogh_-_Starry_Night_-_Google_Art_Project.jpg')

# Visualization of images
plt.imshow(np.squeeze(style_image))
plt.show()
plt.imshow(np.squeeze(content_image))
plt.show()

# Load the model
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# Apply style transfer
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# Display the stylized image
plt.imshow(np.squeeze(stylized_image))
plt.show()

# Save the stylized image
cv2.imwrite('generated_img.jpg', cv2.cvtColor(np.squeeze(stylized_image) * 255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %% [markdown]
# **Scenario 5 ** :
#
# You are developing a style transfer model using GANs to convert photographs of animals into illustrations in a specific artistic style.
#
# Solution:
#
# Collect a dataset of animal photographs and illustrations with the desired artistic style.
#
# Preprocess the images and extract features using a pre-trained neural network.
#
# Implement a GAN architecture suitable for style transfer tasks, incorporating techniques such as conditional GANs or cycle-consistent GANs.
#
# Train the GAN using the animal photographs as input and the illustrations with the desired style as target outputs.
#
# Introduce regularization techniques such as cycle consistency or adversarial loss to ensure faithful style transfer and content preservation.
#
# Fine-tune the model and adjust hyperparameters to achieve the desired balance between realism and stylization.
#
# Validate the model's performance through visual inspection and user feedback, considering factors such as image quality and style fidelity.

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# Load the content & style images
content_image = load_image('/content/Horse.jpg')
style_image = load_image('/content/SpecificArtisticStyle.jpg')

# Visualization of images
plt.imshow(np.squeeze(style_image))
plt.show()
plt.imshow(np.squeeze(content_image))
plt.show()

# Load the model
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# Apply style transfer
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# Display the stylized image
plt.imshow(np.squeeze(stylized_image))
plt.show()

# Save the stylized image
cv2.imwrite('generated_img.jpg', cv2.cvtColor(np.squeeze(stylized_image) * 255, cv2.COLOR_BGR2RGB))
# Out:
# True
